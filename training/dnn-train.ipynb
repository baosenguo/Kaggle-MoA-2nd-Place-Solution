# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/lish-moa/train_targets_scored.csv
# /kaggle/input/lish-moa/sample_submission.csv
# /kaggle/input/lish-moa/train_drug.csv
# /kaggle/input/lish-moa/train_targets_nonscored.csv
# /kaggle/input/lish-moa/train_features.csv
# /kaggle/input/lish-moa/test_features.csv
# /kaggle/input/iterative-stratification/iterative-stratification-master/.travis.yml
# /kaggle/input/iterative-stratification/iterative-stratification-master/setup.cfg
# /kaggle/input/iterative-stratification/iterative-stratification-master/LICENSE
# /kaggle/input/iterative-stratification/iterative-stratification-master/.gitignore
# /kaggle/input/iterative-stratification/iterative-stratification-master/README.md
# /kaggle/input/iterative-stratification/iterative-stratification-master/setup.py
# /kaggle/input/iterative-stratification/iterative-stratification-master/tests/test_ml_stratifiers.py
# /kaggle/input/iterative-stratification/iterative-stratification-master/tests/__init__.py
# /kaggle/input/iterative-stratification/iterative-stratification-master/iterstrat/ml_stratifiers.py
# /kaggle/input/iterative-stratification/iterative-stratification-master/iterstrat/__init__.py

# %%
import sys
sys.path.append('../input/iterative-stratification/iterative-stratification-master')
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import os
import copy
from copy import deepcopy as dp
import seaborn as sns

from sklearn import preprocessing
from sklearn.metrics import log_loss
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import warnings
warnings.filterwarnings('ignore')

def norm_fit(df_1,saveM = True, sc_name = 'zsco'):   
    from sklearn.preprocessing import StandardScaler,MinMaxScaler,MaxAbsScaler,RobustScaler,Normalizer,QuantileTransformer,PowerTransformer
    ss_1_dic = {'zsco':StandardScaler(),
                'mima':MinMaxScaler(),
                'maxb':MaxAbsScaler(), 
                'robu':RobustScaler(),
                'norm':Normalizer(), 
                'quan':QuantileTransformer(n_quantiles=100,random_state=0, output_distribution="normal"),
                'powe':PowerTransformer()}
    ss_1 = ss_1_dic[sc_name]
    df_2 = pd.DataFrame(ss_1.fit_transform(df_1),index = df_1.index,columns = df_1.columns)
    if saveM == False:
        return(df_2)
    else:
        return(df_2,ss_1)

def norm_tra(df_1,ss_x):
    df_2 = pd.DataFrame(ss_x.transform(df_1),index = df_1.index,columns = df_1.columns)
    return(df_2)

def g_table(list1):
    table_dic = {}
    for i in list1:
        if i not in table_dic.keys():
            table_dic[i] = 1
        else:
            table_dic[i] += 1
    return(table_dic)

def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    
seed_everything(seed=42)

# %%
SEED = [200, 201, 202, 203 ,204, 205, 206, 207, 208, 209]

NFOLDS = 7

input_dir = '../input/lish-moa/'

sc_dic = {}
feat_dic = {}
train_features = pd.read_csv(input_dir+'train_features.csv')
train_targets_scored = pd.read_csv(input_dir+'train_targets_scored.csv')
train_targets_nonscored = pd.read_csv(input_dir+'train_targets_nonscored.csv')
test_features = pd.read_csv(input_dir+'test_features.csv')
sample_submission = pd.read_csv(input_dir+'sample_submission.csv')
train_drug = pd.read_csv(input_dir+'train_drug.csv')

target_cols = train_targets_scored.drop('sig_id', axis=1).columns.values.tolist()
aux_target_cols = train_targets_nonscored.drop('sig_id', axis=1).columns.values.tolist()
all_target_cols = target_cols + aux_target_cols

GENES = [col for col in train_features.columns if col.startswith('g-')]
CELLS = [col for col in train_features.columns if col.startswith('c-')]
feat_dic['gene'] = GENES
feat_dic['cell'] = CELLS

# sample norm 
q2 = train_features[feat_dic['gene']].apply(np.quantile,axis = 1,q = 0.25).copy()
q7 = train_features[feat_dic['gene']].apply(np.quantile,axis = 1,q = 0.75).copy()
qmean = (q2+q7)/2
train_features[feat_dic['gene']] = (train_features[feat_dic['gene']].T - qmean.values).T
q2 = test_features[feat_dic['gene']].apply(np.quantile,axis = 1,q = 0.25).copy()
q7 = test_features[feat_dic['gene']].apply(np.quantile,axis = 1,q = 0.75).copy()
qmean = (q2+q7)/2
test_features[feat_dic['gene']] = (test_features[feat_dic['gene']].T - qmean.values).T

q2 = train_features[feat_dic['cell']].apply(np.quantile,axis = 1,q = 0.25).copy()
q7 = train_features[feat_dic['cell']].apply(np.quantile,axis = 1,q = 0.72).copy()
qmean = (q2+q7)/2
train_features[feat_dic['cell']] = (train_features[feat_dic['cell']].T - qmean.values).T
qmean2 = train_features[feat_dic['cell']].abs().apply(np.quantile,axis = 1,q = 0.75).copy()+4
train_features[feat_dic['cell']] = (train_features[feat_dic['cell']].T / qmean2.values).T.copy()

q2 = test_features[feat_dic['cell']].apply(np.quantile,axis = 1,q = 0.25).copy()
q7 = test_features[feat_dic['cell']].apply(np.quantile,axis = 1,q = 0.72).copy()
qmean = (q2+q7)/2
test_features[feat_dic['cell']] = (test_features[feat_dic['cell']].T - qmean.values).T
qmean2 = test_features[feat_dic['cell']].abs().apply(np.quantile,axis = 1,q = 0.75).copy()+4
test_features[feat_dic['cell']] = (test_features[feat_dic['cell']].T / qmean2.values).T.copy()

# remove ctl
train = train_features.merge(train_targets_scored, on='sig_id')
train = train.merge(train_targets_nonscored, on='sig_id')
train = train[train['cp_type']!='ctl_vehicle'].reset_index(drop=True)
test = test_features[test_features['cp_type']!='ctl_vehicle'].reset_index(drop=True)

target = train[train_targets_scored.columns]

train0 = train.drop('cp_type', axis=1)
test = test.drop('cp_type', axis=1)

# drug ids
tar_sig = target['sig_id'].tolist()
train_drug = train_drug.loc[[i in tar_sig for i in train_drug['sig_id']]]
target = target.merge(train_drug, on='sig_id', how='left') 

# LOCATE DRUGS
vc = train_drug.drug_id.value_counts()
vc1 = vc.loc[vc <= 19].index
vc2 = vc.loc[vc > 19].index

feature_cols = []
for key_i in feat_dic.keys():
    value_i = feat_dic[key_i]
    print(key_i,len(value_i))
    feature_cols += value_i
len(feature_cols)
feature_cols0 = dp(feature_cols)
    
oof = np.zeros((len(train), len(target_cols)))
predictions = np.zeros((len(test), len(target_cols)))

# Averaging on multiple SEEDS
for seed in SEED:
    seed_everything(seed=seed)
    folds = train0.copy()
    feature_cols = dp(feature_cols0)
    
    # kfold - leave drug out
    target2 = target.copy()
    dct1 = {}; dct2 = {}
    skf = MultilabelStratifiedKFold(n_splits = NFOLDS) # , shuffle = True, random_state = seed
    tmp = target2.groupby('drug_id')[target_cols].mean().loc[vc1]
    tmp_idx = tmp.index.tolist()
    tmp_idx.sort()
    tmp_idx2 = random.sample(tmp_idx,len(tmp_idx))
    tmp = tmp.loc[tmp_idx2]
    for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_cols])):
        dd = {k:fold for k in tmp.index[idxV].values}
        dct1.update(dd)

    # STRATIFY DRUGS MORE THAN 18X
    skf = MultilabelStratifiedKFold(n_splits = NFOLDS) # , shuffle = True, random_state = seed
    tmp = target2.loc[target2.drug_id.isin(vc2)].reset_index(drop = True)
    tmp_idx = tmp.index.tolist()
    tmp_idx.sort()
    tmp_idx2 = random.sample(tmp_idx,len(tmp_idx))
    tmp = tmp.loc[tmp_idx2]
    for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_cols])):
        dd = {k:fold for k in tmp.sig_id[idxV].values}
        dct2.update(dd)

    target2['kfold'] = target2.drug_id.map(dct1)
    target2.loc[target2.kfold.isna(),'kfold'] = target2.loc[target2.kfold.isna(),'sig_id'].map(dct2)
    target2.kfold = target2.kfold.astype(int)

    folds['kfold'] = target2['kfold'].copy()

    train = folds.copy()
    test_ = test.copy()

    # HyperParameters
    DEVICE = ('cuda' if torch.cuda.is_available() else 'cpu')
    EPOCHS = 24
    BATCH_SIZE = 128

    WEIGHT_DECAY = {'ALL_TARGETS': 1e-5, 'SCORED_ONLY': 3e-6}
    MAX_LR = {'ALL_TARGETS': 1e-2, 'SCORED_ONLY': 3e-3}
    DIV_FACTOR = {'ALL_TARGETS': 1e3, 'SCORED_ONLY': 1e2}
    PCT_START = 0.1

    n_comp1 = 600
    n_comp2 = 50

    num_targets = len(target_cols)
    num_aux_targets = len(aux_target_cols)
    num_all_targets = len(all_target_cols)
    hidden_size=4096

    tar_freq = np.array([np.min(list(g_table(train[target_cols].iloc[:,i]).values())) for i in range(len(target_cols))])
    tar_weight0 = np.array([np.log(i+100) for i in tar_freq])
    tar_weight0_min = dp(np.min(tar_weight0))
    tar_weight = tar_weight0_min/tar_weight0
    pos_weight = torch.tensor(tar_weight).to(DEVICE)

    tar_freq = np.array([np.min(list(g_table(train[all_target_cols].iloc[:,i]).values())) for i in range(len(all_target_cols))])
    tar_weight0 = np.array([np.log(i+100) for i in tar_freq])
    tar_weight0_min = dp(np.min(tar_weight0))
    pos_weight_all = tar_weight0_min/tar_weight0
    pos_weight_all = torch.tensor(pos_weight_all).to(DEVICE)

    from torch.nn.modules.loss import _WeightedLoss
    class SmoothBCEwLogits(_WeightedLoss):
        def __init__(self, weight=None, reduction='mean', smoothing=0.0,pos_weight = None):
            super().__init__(weight=weight, reduction=reduction)
            self.smoothing = smoothing
            self.weight = weight
            self.reduction = reduction
            self.pos_weight = pos_weight

        @staticmethod
        def _smooth(targets:torch.Tensor, n_labels:int, smoothing=0.0):
            assert 0 <= smoothing < 1
            with torch.no_grad():
                targets = targets * (1.0 - smoothing) + 0.5 * smoothing
            return targets

        def forward(self, inputs, targets):
            targets = SmoothBCEwLogits._smooth(targets, inputs.size(-1),
                self.smoothing)
            loss = F.binary_cross_entropy_with_logits(inputs, targets,self.weight,
                                                      pos_weight = self.pos_weight)

            if  self.reduction == 'sum':
                loss = loss.sum()
            elif  self.reduction == 'mean':
                loss = loss.mean()

            return loss

    class TrainDataset:
        def __init__(self, features, targets):
            self.features = features
            self.targets = targets

        def __len__(self):
            return (self.features.shape[0])

        def __getitem__(self, idx):
            dct = {
                'x' : torch.tensor(self.features[idx, :], dtype=torch.float),
                'y' : torch.tensor(self.targets[idx, :], dtype=torch.float)            
            }
            return dct

    class TestDataset:
        def __init__(self, features):
            self.features = features

        def __len__(self):
            return (self.features.shape[0])

        def __getitem__(self, idx):
            dct = {
                'x' : torch.tensor(self.features[idx, :], dtype=torch.float)
            }
            return dct

    def train_fn(model, optimizer, scheduler, loss_fn, dataloader, device):
        model.train()
        final_loss = 0

        for data in dataloader:
            optimizer.zero_grad()
            inputs, targets = data['x'].to(device), data['y'].to(device)
            outputs = model(inputs)
            loss = loss_fn(outputs, targets)
            loss.backward()
            optimizer.step()
            scheduler.step()

            final_loss += loss.item()

        final_loss /= len(dataloader)

        return final_loss

    def valid_fn(model, loss_fn, dataloader, device):
        model.eval()
        final_loss = 0
        valid_preds = []

        for data in dataloader:
            inputs, targets = data['x'].to(device), data['y'].to(device)
            outputs = model(inputs)
            loss = loss_fn(outputs, targets)

            final_loss += loss.item()
            valid_preds.append(outputs.sigmoid().detach().cpu().numpy())

        final_loss /= len(dataloader)
        valid_preds = np.concatenate(valid_preds)

        return final_loss, valid_preds

    def inference_fn(model, dataloader, device):
        model.eval()
        preds = []

        for data in dataloader:
            inputs = data['x'].to(device)
            with torch.no_grad():
                outputs = model(inputs)

            preds.append(outputs.sigmoid().detach().cpu().numpy())

        preds = np.concatenate(preds)

        return preds

    class Model(nn.Module):
        def __init__(self, num_features, num_targets):
            super(Model, self).__init__()
            self.hidden_size = [1500, 1250, 1000, 750]
            self.dropout_value = [0.5, 0.35, 0.3, 0.25]

            self.batch_norm1 = nn.BatchNorm1d(num_features)
            self.dense1 = nn.Linear(num_features, self.hidden_size[0])

            self.batch_norm2 = nn.BatchNorm1d(self.hidden_size[0])
            self.dropout2 = nn.Dropout(self.dropout_value[0])
            self.dense2 = nn.Linear(self.hidden_size[0], self.hidden_size[1])

            self.batch_norm3 = nn.BatchNorm1d(self.hidden_size[1])
            self.dropout3 = nn.Dropout(self.dropout_value[1])
            self.dense3 = nn.Linear(self.hidden_size[1], self.hidden_size[2])

            self.batch_norm4 = nn.BatchNorm1d(self.hidden_size[2])
            self.dropout4 = nn.Dropout(self.dropout_value[2])
            self.dense4 = nn.Linear(self.hidden_size[2], self.hidden_size[3])

            self.batch_norm5 = nn.BatchNorm1d(self.hidden_size[3])
            self.dropout5 = nn.Dropout(self.dropout_value[3])
            self.dense5 = nn.utils.weight_norm(nn.Linear(self.hidden_size[3], num_targets))

        def forward(self, x):
            x = self.batch_norm1(x)
            x = F.leaky_relu(self.dense1(x))

            x = self.batch_norm2(x)
            x = self.dropout2(x)
            x = F.leaky_relu(self.dense2(x))

            x = self.batch_norm3(x)
            x = self.dropout3(x)
            x = F.leaky_relu(self.dense3(x))

            x = self.batch_norm4(x)
            x = self.dropout4(x)
            x = F.leaky_relu(self.dense4(x))

            x = self.batch_norm5(x)
            x = self.dropout5(x)
            x = self.dense5(x)
            return x


    class FineTuneScheduler:
        def __init__(self, epochs):
            self.epochs = epochs
            self.epochs_per_step = 0
            self.frozen_layers = []

        def copy_without_top(self, model, num_features, num_targets, num_targets_new):
            self.frozen_layers = []

            model_new = Model(num_features, num_targets)
            model_new.load_state_dict(model.state_dict())

            # Freeze all weights
            for name, param in model_new.named_parameters():
                layer_index = name.split('.')[0][-1]

                if layer_index == '5':
                    continue

                param.requires_grad = False

                # Save frozen layer names
                if layer_index not in self.frozen_layers:
                    self.frozen_layers.append(layer_index)

            self.epochs_per_step = self.epochs // len(self.frozen_layers)

            # Replace the top layers with another ones
            model_new.batch_norm5 = nn.BatchNorm1d(model_new.hidden_size[3])
            model_new.dropout5 = nn.Dropout(model_new.dropout_value[3])
            model_new.dense5 = nn.utils.weight_norm(nn.Linear(model_new.hidden_size[-1], num_targets_new))
            model_new.to(DEVICE)
            return model_new

        def step(self, epoch, model):
            if len(self.frozen_layers) == 0:
                return

            if epoch % self.epochs_per_step == 0:
                last_frozen_index = self.frozen_layers[-1]

                # Unfreeze parameters of the last frozen layer
                for name, param in model.named_parameters():
                    layer_index = name.split('.')[0][-1]

                    if layer_index == last_frozen_index:
                        param.requires_grad = True

                del self.frozen_layers[-1]  # Remove the last layer as unfrozen

    def run_training(fold, seed):

        seed_everything(seed)

        trn_idx = train[train['kfold'] != fold].index
        val_idx = train[train['kfold'] == fold].index

        train_df = train[train['kfold'] != fold].reset_index(drop=True).copy()
        valid_df = train[train['kfold'] == fold].reset_index(drop=True).copy()

        x_train, y_train, y_train_all  = train_df[feature_cols], train_df[target_cols].values, train_df[all_target_cols].values
        x_valid, y_valid, y_valid_all =  valid_df[feature_cols], valid_df[target_cols].values, valid_df[all_target_cols].values
        x_test = test_[feature_cols]

        #------------ norm --------------
        col_num = list(set(feat_dic['gene'] + feat_dic['cell']) & set(feature_cols))
        col_num.sort()
        x_train[col_num],ss = norm_fit(x_train[col_num],True,'quan')
        x_valid[col_num]    = norm_tra(x_valid[col_num],ss)
        x_test[col_num]     = norm_tra(x_test[col_num],ss)

        #------------ pca --------------
        def pca_pre(tr,va,te,
                    n_comp,feat_raw,feat_new):
            pca = PCA(n_components=n_comp, random_state=42)
            tr2 = pd.DataFrame(pca.fit_transform(tr[feat_raw]),columns=feat_new)
            va2 = pd.DataFrame(pca.transform(va[feat_raw]),columns=feat_new)
            te2 = pd.DataFrame(pca.transform(te[feat_raw]),columns=feat_new)
            return(tr2,va2,te2)

        pca_feat_g = [f'pca_G-{i}' for i in range(n_comp1)]
        feat_dic['pca_g'] = pca_feat_g
        x_tr_g_pca,x_va_g_pca,x_te_g_pca = pca_pre(x_train,x_valid,x_test,
                                                   n_comp1,feat_dic['gene'],pca_feat_g)
        x_train = pd.concat([x_train,x_tr_g_pca],axis = 1)
        x_valid = pd.concat([x_valid,x_va_g_pca],axis = 1)
        x_test  = pd.concat([x_test,x_te_g_pca],axis = 1)

        pca_feat_g = [f'pca_C-{i}' for i in range(n_comp2)]
        feat_dic['pca_c'] = pca_feat_g
        x_tr_c_pca,x_va_c_pca,x_te_c_pca = pca_pre(x_train,x_valid,x_test,
                                                   n_comp2,feat_dic['cell'],pca_feat_g)
        x_train = pd.concat([x_train,x_tr_c_pca],axis = 1)
        x_valid = pd.concat([x_valid,x_va_c_pca],axis = 1)
        x_test  = pd.concat([x_test,x_te_c_pca], axis = 1)

        #------------ var --------------
        from sklearn.feature_selection import VarianceThreshold
        var_thresh = VarianceThreshold(0.8)
        var_thresh.fit(x_train)
        x_train = x_train.loc[:,var_thresh.variances_ > 0.8]
        x_valid = x_valid.loc[:,var_thresh.variances_ > 0.8]
        x_test  = x_test.loc[:,var_thresh.variances_  > 0.8]

        num_features = x_train.shape[1]

        x_train,x_valid,x_test = x_train.values,x_valid.values,x_test.values

        def train_model(model, tag_name, target_cols_now, fine_tune_scheduler=None):
            if tag_name == 'ALL_TARGETS':
                train_dataset = TrainDataset(x_train, y_train_all)
                valid_dataset = TrainDataset(x_valid, y_valid_all)
            else:
                train_dataset = TrainDataset(x_train, y_train)
                valid_dataset = TrainDataset(x_valid, y_valid)

            trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            validloader = torch.utils.data.DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False)

            optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=WEIGHT_DECAY[tag_name])
            scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer,
                                                      steps_per_epoch=len(trainloader),
                                                      pct_start=PCT_START,
                                                      div_factor=DIV_FACTOR[tag_name], 
                                                      max_lr=MAX_LR[tag_name],
                                                      epochs=EPOCHS)

            if tag_name == 'ALL_TARGETS':
                loss_tr = SmoothBCEwLogits(smoothing=0.001,pos_weight = pos_weight_all)
            else:
                loss_tr = SmoothBCEwLogits(smoothing=0.001,pos_weight = pos_weight)
            loss_fn = nn.BCEWithLogitsLoss()

            oof = np.zeros((len(train), len(target_cols_now)))
            best_loss = np.inf

            mod_name = f"mod31_{tag_name}_{seed}_{fold}.pth"
            for epoch in range(EPOCHS):
                if fine_tune_scheduler is not None:
                    fine_tune_scheduler.step(epoch, model)
                train_loss = train_fn(model, optimizer, scheduler, loss_tr, trainloader, DEVICE)
                valid_loss, valid_preds = valid_fn(model, loss_fn, validloader, DEVICE)
                print(f"SEED: {seed}, FOLD: {fold}, {tag_name}, EPOCH: {epoch}, train_loss: {train_loss:.6f}, valid_loss: {valid_loss:.6f}")
                if np.isnan(valid_loss):
                    break
                if valid_loss < best_loss:
                    best_loss = valid_loss
                    oof[val_idx] = valid_preds
                    torch.save(model.state_dict(),mod_name )
            return oof

        fine_tune_scheduler = FineTuneScheduler(EPOCHS)

        pretrained_model = Model(num_features, num_all_targets)
        pretrained_model.to(DEVICE)

        # Train on scored + nonscored targets
        train_model(pretrained_model, 'ALL_TARGETS', all_target_cols)

        tag_name = 'ALL_TARGETS'
        mod_name = f"mod31_{tag_name}_{seed}_{fold}.pth"
        # Load the pretrained model with the best loss
        pretrained_model = Model(num_features, num_all_targets)
        pretrained_model.load_state_dict(torch.load(mod_name))
        pretrained_model.to(DEVICE)

        # Copy model without the top layer
        final_model = fine_tune_scheduler.copy_without_top(pretrained_model, num_features, num_all_targets, num_targets)

        # Fine-tune the model on scored targets only
        oof = train_model(final_model, 'SCORED_ONLY', target_cols, fine_tune_scheduler)

        tag_name = 'SCORED_ONLY'
        mod_name = f"mod31_{tag_name}_{seed}_{fold}.pth"
        # Load the fine-tuned model with the best loss
        model = Model(num_features, num_targets)
        model.load_state_dict(torch.load(mod_name))
        model.to(DEVICE)

        #--------------------- PREDICTION---------------------
        testdataset = TestDataset(x_test)
        testloader = torch.utils.data.DataLoader(testdataset, batch_size=BATCH_SIZE, shuffle=False)

        predictions = np.zeros((len(test_), num_targets))
        predictions = inference_fn(model, testloader, DEVICE)
        return oof, predictions


    def run_k_fold(NFOLDS, seed):
        oof = np.zeros((len(train), len(target_cols)))
        predictions = np.zeros((len(test), len(target_cols)))

        for fold in range(NFOLDS):
            oof_, pred_ = run_training(fold, seed)

            predictions += pred_ / NFOLDS
            oof += oof_

        return oof, predictions


    oof_, predictions_ = run_k_fold(NFOLDS, seed)
    oof += oof_ / len(SEED)
    predictions += predictions_ / len(SEED)
    
    oof_tmp = dp(oof)
    oof_tmp = oof_tmp * len(SEED) / (SEED.index(seed)+1)
    sc_dic[seed] = np.mean([log_loss(train[target_cols].iloc[:,i],oof_tmp[:,i]) for i in range(len(target_cols))])
    
from sklearn.metrics import log_loss
print(np.mean([log_loss(train[target_cols].iloc[:,i],oof[:,i]) for i in range(len(target_cols))]))

train0[target_cols] = oof
test[target_cols] = predictions

### for blend test ###
train0.to_csv('train_pred.csv', index=False)
### for blend test ###

sub = sample_submission.drop(columns=target_cols).merge(test[['sig_id']+target_cols], on='sig_id', how='left').fillna(0)
sub.to_csv('submission.csv', index=False)
# Out:
# gene 772
# cell 100
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 0, train_loss: 0.497363, valid_loss: 0.021718
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 1, train_loss: 0.014223, valid_loss: 0.010257
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 2, train_loss: 0.012332, valid_loss: 0.009509
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 3, train_loss: 0.011742, valid_loss: 0.009402
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 4, train_loss: 0.011710, valid_loss: 0.009299
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 5, train_loss: 0.011632, valid_loss: 0.009353
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 6, train_loss: 0.011616, valid_loss: 0.009287
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 7, train_loss: 0.011599, valid_loss: 0.009278
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 8, train_loss: 0.011619, valid_loss: 0.009260
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 9, train_loss: 0.011610, valid_loss: 0.009335
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 10, train_loss: 0.011588, valid_loss: 0.009377
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 11, train_loss: 0.011578, valid_loss: 0.009317
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 12, train_loss: 0.011558, valid_loss: 0.009351
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 13, train_loss: 0.011532, valid_loss: 0.009281
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 14, train_loss: 0.011494, valid_loss: 0.009212
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 15, train_loss: 0.011476, valid_loss: 0.009261
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 16, train_loss: 0.011423, valid_loss: 0.009185
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 17, train_loss: 0.011360, valid_loss: 0.009170
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 18, train_loss: 0.011295, valid_loss: 0.009117
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 19, train_loss: 0.011204, valid_loss: 0.009068
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 20, train_loss: 0.011116, valid_loss: 0.008969
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 21, train_loss: 0.011022, valid_loss: 0.008934
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 22, train_loss: 0.010938, valid_loss: 0.008901
# SEED: 200, FOLD: 0, ALL_TARGETS, EPOCH: 23, train_loss: 0.010895, valid_loss: 0.008891
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 0, train_loss: 0.640741, valid_loss: 0.219528
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 1, train_loss: 0.057603, valid_loss: 0.019761
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 2, train_loss: 0.018979, valid_loss: 0.018075
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 3, train_loss: 0.017753, valid_loss: 0.017728
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 4, train_loss: 0.017512, valid_loss: 0.017683
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 5, train_loss: 0.017345, valid_loss: 0.017673
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 6, train_loss: 0.017614, valid_loss: 0.017694
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 7, train_loss: 0.017402, valid_loss: 0.017728
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 8, train_loss: 0.017246, valid_loss: 0.017813
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 9, train_loss: 0.017157, valid_loss: 0.017557
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 10, train_loss: 0.017189, valid_loss: 0.018060
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 11, train_loss: 0.017195, valid_loss: 0.017632
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 12, train_loss: 0.017287, valid_loss: 0.017820
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 13, train_loss: 0.017045, valid_loss: 0.017618
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 14, train_loss: 0.016921, valid_loss: 0.017472
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 15, train_loss: 0.016767, valid_loss: 0.017507
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 16, train_loss: 0.016632, valid_loss: 0.017602
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 17, train_loss: 0.016570, valid_loss: 0.017526
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 18, train_loss: 0.016632, valid_loss: 0.017593
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 19, train_loss: 0.016285, valid_loss: 0.017609
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 20, train_loss: 0.016026, valid_loss: 0.017552
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 21, train_loss: 0.015786, valid_loss: 0.017554
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 22, train_loss: 0.015634, valid_loss: 0.017582
# SEED: 200, FOLD: 0, SCORED_ONLY, EPOCH: 23, train_loss: 0.015576, valid_loss: 0.017574
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 0, train_loss: 0.496025, valid_loss: 0.019007
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 1, train_loss: 0.014400, valid_loss: 0.010023
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 2, train_loss: 0.012203, valid_loss: 0.009623
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 3, train_loss: 0.011786, valid_loss: 0.009349
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 4, train_loss: 0.011746, valid_loss: 0.009366
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 5, train_loss: 0.011712, valid_loss: 0.009548
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 6, train_loss: 0.011700, valid_loss: 0.009380
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 7, train_loss: 0.011673, valid_loss: 0.009222
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 8, train_loss: 0.011693, valid_loss: 0.009332
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 9, train_loss: 0.011620, valid_loss: 0.009399
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 10, train_loss: 0.011631, valid_loss: 0.009413
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 11, train_loss: 0.011616, valid_loss: 0.009327
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 12, train_loss: 0.011598, valid_loss: 0.009308
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 13, train_loss: 0.011578, valid_loss: 0.009248
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 14, train_loss: 0.011543, valid_loss: 0.009253
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 15, train_loss: 0.011501, valid_loss: 0.009280
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 16, train_loss: 0.011466, valid_loss: 0.009100
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 17, train_loss: 0.011388, valid_loss: 0.009099
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 18, train_loss: 0.011329, valid_loss: 0.009059
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 19, train_loss: 0.011260, valid_loss: 0.009027
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 20, train_loss: 0.011154, valid_loss: 0.008952
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 21, train_loss: 0.011063, valid_loss: 0.008897
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 22, train_loss: 0.010984, valid_loss: 0.008879
# SEED: 200, FOLD: 1, ALL_TARGETS, EPOCH: 23, train_loss: 0.010938, valid_loss: 0.008881
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 0, train_loss: 0.640494, valid_loss: 0.261756
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 1, train_loss: 0.056855, valid_loss: 0.020275
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 2, train_loss: 0.018964, valid_loss: 0.018184
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 3, train_loss: 0.017932, valid_loss: 0.017828
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 4, train_loss: 0.017624, valid_loss: 0.017779
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 5, train_loss: 0.017472, valid_loss: 0.017634
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 6, train_loss: 0.017676, valid_loss: 0.017806
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 7, train_loss: 0.017472, valid_loss: 0.017651
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 8, train_loss: 0.017340, valid_loss: 0.017611
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 9, train_loss: 0.017331, valid_loss: 0.017625
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 10, train_loss: 0.017250, valid_loss: 0.017609
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 11, train_loss: 0.017176, valid_loss: 0.017689
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 12, train_loss: 0.017391, valid_loss: 0.017736
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 13, train_loss: 0.017220, valid_loss: 0.017549
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 14, train_loss: 0.017035, valid_loss: 0.017626
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 15, train_loss: 0.016916, valid_loss: 0.017616
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 16, train_loss: 0.016767, valid_loss: 0.017522
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 17, train_loss: 0.016646, valid_loss: 0.017533
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 18, train_loss: 0.016796, valid_loss: 0.017525
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 19, train_loss: 0.016444, valid_loss: 0.017500
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 20, train_loss: 0.016135, valid_loss: 0.017436
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 21, train_loss: 0.015942, valid_loss: 0.017488
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 22, train_loss: 0.015778, valid_loss: 0.017452
# SEED: 200, FOLD: 1, SCORED_ONLY, EPOCH: 23, train_loss: 0.015740, valid_loss: 0.017453
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 0, train_loss: 0.496816, valid_loss: 0.020140
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 1, train_loss: 0.014532, valid_loss: 0.010176
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 2, train_loss: 0.012372, valid_loss: 0.009678
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 3, train_loss: 0.011788, valid_loss: 0.009595
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 4, train_loss: 0.011918, valid_loss: 0.009442
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 5, train_loss: 0.011592, valid_loss: 0.009487
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 6, train_loss: 0.011641, valid_loss: 0.009408
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 7, train_loss: 0.011596, valid_loss: 0.009501
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 8, train_loss: 0.011601, valid_loss: 0.009529
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 9, train_loss: 0.011611, valid_loss: 0.009360
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 10, train_loss: 0.011559, valid_loss: 0.009484
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 11, train_loss: 0.011570, valid_loss: 0.009389
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 12, train_loss: 0.011558, valid_loss: 0.009472
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 13, train_loss: 0.011545, valid_loss: 0.009406
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 14, train_loss: 0.011495, valid_loss: 0.009329
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 15, train_loss: 0.011456, valid_loss: 0.009351
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 16, train_loss: 0.011411, valid_loss: 0.009329
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 17, train_loss: 0.011359, valid_loss: 0.009297
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 18, train_loss: 0.011279, valid_loss: 0.009233
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 19, train_loss: 0.011202, valid_loss: 0.009110
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 20, train_loss: 0.011116, valid_loss: 0.009123
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 21, train_loss: 0.011016, valid_loss: 0.009075
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 22, train_loss: 0.010936, valid_loss: 0.009034
# SEED: 200, FOLD: 2, ALL_TARGETS, EPOCH: 23, train_loss: 0.010885, valid_loss: 0.009029
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 0, train_loss: 0.642013, valid_loss: 0.260454
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 1, train_loss: 0.056838, valid_loss: 0.020029
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 2, train_loss: 0.019016, valid_loss: 0.017700
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 3, train_loss: 0.017884, valid_loss: 0.017320
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 4, train_loss: 0.017559, valid_loss: 0.017287
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 5, train_loss: 0.017440, valid_loss: 0.017340
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 6, train_loss: 0.017827, valid_loss: 0.017237
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 7, train_loss: 0.017478, valid_loss: 0.017136
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 8, train_loss: 0.017358, valid_loss: 0.017230
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 9, train_loss: 0.017278, valid_loss: 0.017163
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 10, train_loss: 0.017195, valid_loss: 0.017201
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 11, train_loss: 0.017204, valid_loss: 0.017134
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 12, train_loss: 0.017408, valid_loss: 0.017137
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 13, train_loss: 0.017153, valid_loss: 0.017165
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 14, train_loss: 0.017012, valid_loss: 0.017010
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 15, train_loss: 0.016887, valid_loss: 0.017086
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 16, train_loss: 0.016738, valid_loss: 0.017044
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 17, train_loss: 0.016610, valid_loss: 0.016997
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 18, train_loss: 0.016747, valid_loss: 0.016999
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 19, train_loss: 0.016373, valid_loss: 0.017012
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 20, train_loss: 0.016093, valid_loss: 0.016967
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 21, train_loss: 0.015814, valid_loss: 0.016960
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 22, train_loss: 0.015658, valid_loss: 0.016976
# SEED: 200, FOLD: 2, SCORED_ONLY, EPOCH: 23, train_loss: 0.015618, valid_loss: 0.016986
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 0, train_loss: 0.497552, valid_loss: 0.018873
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 1, train_loss: 0.014301, valid_loss: 0.010330
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 2, train_loss: 0.012023, valid_loss: 0.009738
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 3, train_loss: 0.011768, valid_loss: 0.009494
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 4, train_loss: 0.011613, valid_loss: 0.009940
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 5, train_loss: 0.011625, valid_loss: 0.009485
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 6, train_loss: 0.011554, valid_loss: 0.009663
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 7, train_loss: 0.011634, valid_loss: 0.009443
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 8, train_loss: 0.011589, valid_loss: 0.009509
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 9, train_loss: 0.011552, valid_loss: 0.009543
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 10, train_loss: 0.011559, valid_loss: 0.009477
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 11, train_loss: 0.011533, valid_loss: 0.009532
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 12, train_loss: 0.011526, valid_loss: 0.009341
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 13, train_loss: 0.011517, valid_loss: 0.009467
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 14, train_loss: 0.011468, valid_loss: 0.009424
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 15, train_loss: 0.011411, valid_loss: 0.009441
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 16, train_loss: 0.011394, valid_loss: 0.009289
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 17, train_loss: 0.011319, valid_loss: 0.009262
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 18, train_loss: 0.011242, valid_loss: 0.009191
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 19, train_loss: 0.011169, valid_loss: 0.009211
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 20, train_loss: 0.011081, valid_loss: 0.009114
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 21, train_loss: 0.010979, valid_loss: 0.009053
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 22, train_loss: 0.010893, valid_loss: 0.009034
# SEED: 200, FOLD: 3, ALL_TARGETS, EPOCH: 23, train_loss: 0.010848, valid_loss: 0.009040
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 0, train_loss: 0.641503, valid_loss: 0.268716
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 1, train_loss: 0.058122, valid_loss: 0.024016
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 2, train_loss: 0.018866, valid_loss: 0.018034
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 3, train_loss: 0.017797, valid_loss: 0.017516
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 4, train_loss: 0.017503, valid_loss: 0.017342
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 5, train_loss: 0.017356, valid_loss: 0.017293
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 6, train_loss: 0.018061, valid_loss: 0.017433
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 7, train_loss: 0.017445, valid_loss: 0.017362
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 8, train_loss: 0.017301, valid_loss: 0.017184
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 9, train_loss: 0.017244, valid_loss: 0.017174
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 10, train_loss: 0.017176, valid_loss: 0.017276
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 11, train_loss: 0.017116, valid_loss: 0.017123
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 12, train_loss: 0.017325, valid_loss: 0.017246
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 13, train_loss: 0.017103, valid_loss: 0.017157
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 14, train_loss: 0.016971, valid_loss: 0.017235
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 15, train_loss: 0.016788, valid_loss: 0.017211
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 16, train_loss: 0.016712, valid_loss: 0.017165
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 17, train_loss: 0.016580, valid_loss: 0.017127
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 18, train_loss: 0.016697, valid_loss: 0.017160
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 19, train_loss: 0.016389, valid_loss: 0.017143
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 20, train_loss: 0.016120, valid_loss: 0.017169
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 21, train_loss: 0.015849, valid_loss: 0.017113
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 22, train_loss: 0.015724, valid_loss: 0.017123
# SEED: 200, FOLD: 3, SCORED_ONLY, EPOCH: 23, train_loss: 0.015656, valid_loss: 0.017112
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 0, train_loss: 0.494818, valid_loss: 0.019033
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 1, train_loss: 0.014056, valid_loss: 0.011076
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 2, train_loss: 0.012440, valid_loss: 0.014271
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 3, train_loss: 0.013010, valid_loss: 0.010649
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 4, train_loss: 0.011857, valid_loss: 0.010433
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 5, train_loss: 0.011677, valid_loss: 0.011199
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 6, train_loss: 0.011709, valid_loss: 0.010427
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 7, train_loss: 0.011584, valid_loss: 0.010498
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 8, train_loss: 0.011610, valid_loss: 0.010700
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 9, train_loss: 0.011560, valid_loss: 0.010130
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 10, train_loss: 0.011528, valid_loss: 0.010174
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 11, train_loss: 0.011482, valid_loss: 0.010103
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 12, train_loss: 0.011492, valid_loss: 0.010157
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 13, train_loss: 0.011430, valid_loss: 0.010059
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 14, train_loss: 0.011397, valid_loss: 0.010010
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 15, train_loss: 0.011379, valid_loss: 0.009997
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 16, train_loss: 0.011346, valid_loss: 0.009920
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 17, train_loss: 0.011263, valid_loss: 0.009898
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 18, train_loss: 0.011197, valid_loss: 0.009851
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 19, train_loss: 0.011123, valid_loss: 0.009828
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 20, train_loss: 0.011036, valid_loss: 0.009773
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 21, train_loss: 0.010975, valid_loss: 0.009707
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 22, train_loss: 0.010854, valid_loss: 0.009687
# SEED: 200, FOLD: 4, ALL_TARGETS, EPOCH: 23, train_loss: 0.010821, valid_loss: 0.009680
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 0, train_loss: 0.639024, valid_loss: 0.204310
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 1, train_loss: 0.056283, valid_loss: 0.019433
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 2, train_loss: 0.018918, valid_loss: 0.018165
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 3, train_loss: 0.017737, valid_loss: 0.017979
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 4, train_loss: 0.017531, valid_loss: 0.017802
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 5, train_loss: 0.017331, valid_loss: 0.017861
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 6, train_loss: 0.017586, valid_loss: 0.017791
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 7, train_loss: 0.017341, valid_loss: 0.017806
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 8, train_loss: 0.017271, valid_loss: 0.017844
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 9, train_loss: 0.017189, valid_loss: 0.017787
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 10, train_loss: 0.017127, valid_loss: 0.017771
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 11, train_loss: 0.017128, valid_loss: 0.017731
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 12, train_loss: 0.017413, valid_loss: 0.017788
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 13, train_loss: 0.017282, valid_loss: 0.017761
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 14, train_loss: 0.017000, valid_loss: 0.017726
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 15, train_loss: 0.016823, valid_loss: 0.017733
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 16, train_loss: 0.016658, valid_loss: 0.017742
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 17, train_loss: 0.016523, valid_loss: 0.017752
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 18, train_loss: 0.016722, valid_loss: 0.017699
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 19, train_loss: 0.016359, valid_loss: 0.017713
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 20, train_loss: 0.016074, valid_loss: 0.017724
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 21, train_loss: 0.015794, valid_loss: 0.017735
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 22, train_loss: 0.015574, valid_loss: 0.017739
# SEED: 200, FOLD: 4, SCORED_ONLY, EPOCH: 23, train_loss: 0.015517, valid_loss: 0.017723
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 0, train_loss: 0.493966, valid_loss: 0.020473
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 1, train_loss: 0.014299, valid_loss: 0.013416
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 2, train_loss: 0.012193, valid_loss: 0.011398
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 3, train_loss: 0.012573, valid_loss: 1.558945
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 4, train_loss: 0.012404, valid_loss: 0.010183
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 5, train_loss: 0.011760, valid_loss: 0.009916
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 6, train_loss: 0.011654, valid_loss: 0.009957
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 7, train_loss: 0.011641, valid_loss: 0.009891
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 8, train_loss: 0.011644, valid_loss: 0.009785
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 9, train_loss: 0.011607, valid_loss: 0.009830
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 10, train_loss: 0.011599, valid_loss: 0.009793
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 11, train_loss: 0.011587, valid_loss: 0.009743
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 12, train_loss: 0.011538, valid_loss: 0.009754
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 13, train_loss: 0.011498, valid_loss: 0.009717
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 14, train_loss: 0.011514, valid_loss: 0.009686
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 15, train_loss: 0.011433, valid_loss: 0.009538
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 16, train_loss: 0.011373, valid_loss: 0.009525
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 17, train_loss: 0.011337, valid_loss: 0.009450
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 18, train_loss: 0.011269, valid_loss: 0.009455
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 19, train_loss: 0.011201, valid_loss: 0.009342
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 20, train_loss: 0.011065, valid_loss: 0.009328
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 21, train_loss: 0.010977, valid_loss: 0.009263
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 22, train_loss: 0.010900, valid_loss: 0.009260
# SEED: 200, FOLD: 5, ALL_TARGETS, EPOCH: 23, train_loss: 0.010867, valid_loss: 0.009237
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 0, train_loss: 0.638743, valid_loss: 0.234256
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 1, train_loss: 0.056742, valid_loss: 0.019895
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 2, train_loss: 0.019068, valid_loss: 0.017733
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 3, train_loss: 0.017851, valid_loss: 0.017751
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 4, train_loss: 0.017554, valid_loss: 0.017607
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 5, train_loss: 0.017439, valid_loss: 0.017677
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 6, train_loss: 0.017676, valid_loss: 0.017637
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 7, train_loss: 0.017407, valid_loss: 0.017578
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 8, train_loss: 0.017399, valid_loss: 0.017489
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 9, train_loss: 0.017277, valid_loss: 0.017551
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 10, train_loss: 0.017206, valid_loss: 0.017489
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 11, train_loss: 0.017166, valid_loss: 0.017579
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 12, train_loss: 0.017412, valid_loss: 0.017547
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 13, train_loss: 0.017119, valid_loss: 0.017505
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 14, train_loss: 0.017013, valid_loss: 0.017399
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 15, train_loss: 0.016896, valid_loss: 0.017445
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 16, train_loss: 0.016727, valid_loss: 0.017430
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 17, train_loss: 0.016628, valid_loss: 0.017399
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 18, train_loss: 0.016835, valid_loss: 0.017430
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 19, train_loss: 0.016461, valid_loss: 0.017397
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 20, train_loss: 0.016135, valid_loss: 0.017330
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 21, train_loss: 0.015857, valid_loss: 0.017347
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 22, train_loss: 0.015732, valid_loss: 0.017368
# SEED: 200, FOLD: 5, SCORED_ONLY, EPOCH: 23, train_loss: 0.015681, valid_loss: 0.017352
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 0, train_loss: 0.494837, valid_loss: 0.022607
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 1, train_loss: 0.014338, valid_loss: 0.010167
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 2, train_loss: 0.012023, valid_loss: 0.009722
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 3, train_loss: 0.011936, valid_loss: 0.009522
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 4, train_loss: 0.011634, valid_loss: 0.009479
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 5, train_loss: 0.011585, valid_loss: 0.009528
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 6, train_loss: 0.011618, valid_loss: 0.009661
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 7, train_loss: 0.011589, valid_loss: 0.009476
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 8, train_loss: 0.011569, valid_loss: 0.009435
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 9, train_loss: 0.011582, valid_loss: 0.009456
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 10, train_loss: 0.011559, valid_loss: 0.009457
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 11, train_loss: 0.011552, valid_loss: 0.009340
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 12, train_loss: 0.011564, valid_loss: 0.009444
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 13, train_loss: 0.011533, valid_loss: 0.009351
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 14, train_loss: 0.011497, valid_loss: 0.009348
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 15, train_loss: 0.011449, valid_loss: 0.009280
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 16, train_loss: 0.011398, valid_loss: 0.009248
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 17, train_loss: 0.011342, valid_loss: 0.009137
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 18, train_loss: 0.011268, valid_loss: 0.009102
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 19, train_loss: 0.011170, valid_loss: 0.009071
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 20, train_loss: 0.011091, valid_loss: 0.009011
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 21, train_loss: 0.010998, valid_loss: 0.008971
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 22, train_loss: 0.010912, valid_loss: 0.008949
# SEED: 200, FOLD: 6, ALL_TARGETS, EPOCH: 23, train_loss: 0.010864, valid_loss: 0.008951
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 0, train_loss: 0.636411, valid_loss: 0.257017
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 1, train_loss: 0.056539, valid_loss: 0.019273
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 2, train_loss: 0.019012, valid_loss: 0.017250
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 3, train_loss: 0.017975, valid_loss: 0.016735
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 4, train_loss: 0.017666, valid_loss: 0.016616
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 5, train_loss: 0.017513, valid_loss: 0.016659
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 6, train_loss: 0.017787, valid_loss: 0.016598
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 7, train_loss: 0.017497, valid_loss: 0.016537
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 8, train_loss: 0.017419, valid_loss: 0.016544
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 9, train_loss: 0.017388, valid_loss: 0.016534
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 10, train_loss: 0.017272, valid_loss: 0.016448
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 11, train_loss: 0.017216, valid_loss: 0.016563
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 12, train_loss: 0.017482, valid_loss: 0.016547
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 13, train_loss: 0.017255, valid_loss: 0.016451
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 14, train_loss: 0.017082, valid_loss: 0.016514
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 15, train_loss: 0.016947, valid_loss: 0.016479
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 16, train_loss: 0.016838, valid_loss: 0.016491
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 17, train_loss: 0.016707, valid_loss: 0.016424
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 18, train_loss: 0.016881, valid_loss: 0.016449
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 19, train_loss: 0.016483, valid_loss: 0.016370
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 20, train_loss: 0.016205, valid_loss: 0.016408
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 21, train_loss: 0.015953, valid_loss: 0.016397
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 22, train_loss: 0.015833, valid_loss: 0.016419
# SEED: 200, FOLD: 6, SCORED_ONLY, EPOCH: 23, train_loss: 0.015760, valid_loss: 0.016398
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 0, train_loss: 0.495972, valid_loss: 0.022533
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 1, train_loss: 0.014186, valid_loss: 0.010469
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 2, train_loss: 0.012017, valid_loss: 0.009966
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 3, train_loss: 0.011697, valid_loss: 0.011414
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 4, train_loss: 0.011742, valid_loss: 0.009640
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 5, train_loss: 0.011531, valid_loss: 0.009655
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 6, train_loss: 0.011585, valid_loss: 0.009892
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 7, train_loss: 0.011573, valid_loss: 0.009709
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 8, train_loss: 0.011544, valid_loss: 0.009709
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 9, train_loss: 0.011539, valid_loss: 0.009670
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 10, train_loss: 0.011515, valid_loss: 0.009792
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 11, train_loss: 0.011526, valid_loss: 0.009747
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 12, train_loss: 0.011497, valid_loss: 0.009742
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 13, train_loss: 0.011491, valid_loss: 0.009638
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 14, train_loss: 0.011466, valid_loss: 0.009641
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 15, train_loss: 0.011422, valid_loss: 0.009544
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 16, train_loss: 0.011378, valid_loss: 0.009583
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 17, train_loss: 0.011308, valid_loss: 0.009531
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 18, train_loss: 0.011234, valid_loss: 0.009453
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 19, train_loss: 0.011145, valid_loss: 0.009408
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 20, train_loss: 0.011059, valid_loss: 0.009434
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 21, train_loss: 0.010967, valid_loss: 0.009310
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 22, train_loss: 0.010886, valid_loss: 0.009293
# SEED: 201, FOLD: 0, ALL_TARGETS, EPOCH: 23, train_loss: 0.010834, valid_loss: 0.009276
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 0, train_loss: 0.640943, valid_loss: 0.254314
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 1, train_loss: 0.057647, valid_loss: 0.020306
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 2, train_loss: 0.018944, valid_loss: 0.018328
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 3, train_loss: 0.017801, valid_loss: 0.018034
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 4, train_loss: 0.017536, valid_loss: 0.017892
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 5, train_loss: 0.017393, valid_loss: 0.017810
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 6, train_loss: 0.017728, valid_loss: 0.017884
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 7, train_loss: 0.017396, valid_loss: 0.017788
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 8, train_loss: 0.017307, valid_loss: 0.018018
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 9, train_loss: 0.017218, valid_loss: 0.017852
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 10, train_loss: 0.017162, valid_loss: 0.017838
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 11, train_loss: 0.017061, valid_loss: 0.017717
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 12, train_loss: 0.017308, valid_loss: 0.017849
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 13, train_loss: 0.017069, valid_loss: 0.017785
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 14, train_loss: 0.016935, valid_loss: 0.017707
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 15, train_loss: 0.016824, valid_loss: 0.017705
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 16, train_loss: 0.016670, valid_loss: 0.017667
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 17, train_loss: 0.016579, valid_loss: 0.017655
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 18, train_loss: 0.016673, valid_loss: 0.017761
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 19, train_loss: 0.016311, valid_loss: 0.017631
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 20, train_loss: 0.016018, valid_loss: 0.017655
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 21, train_loss: 0.015776, valid_loss: 0.017673
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 22, train_loss: 0.015613, valid_loss: 0.017689
# SEED: 201, FOLD: 0, SCORED_ONLY, EPOCH: 23, train_loss: 0.015522, valid_loss: 0.017655
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 0, train_loss: 0.496310, valid_loss: 0.021550
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 1, train_loss: 0.014488, valid_loss: 0.010393
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 2, train_loss: 0.012073, valid_loss: 0.009685
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 3, train_loss: 0.011975, valid_loss: 0.009535
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 4, train_loss: 0.011649, valid_loss: 0.009555
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 5, train_loss: 0.011597, valid_loss: 0.009565
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 6, train_loss: 0.011590, valid_loss: 0.009497
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 7, train_loss: 0.011596, valid_loss: 0.009644
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 8, train_loss: 0.011591, valid_loss: 0.009554
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 9, train_loss: 0.011566, valid_loss: 0.009488
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 10, train_loss: 0.011568, valid_loss: 0.009564
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 11, train_loss: 0.011539, valid_loss: 0.009550
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 12, train_loss: 0.011542, valid_loss: 0.009486
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 13, train_loss: 0.011515, valid_loss: 0.009408
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 14, train_loss: 0.011512, valid_loss: 0.009440
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 15, train_loss: 0.011459, valid_loss: 0.009410
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 16, train_loss: 0.011376, valid_loss: 0.009295
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 17, train_loss: 0.011340, valid_loss: 0.009325
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 18, train_loss: 0.011300, valid_loss: 0.009260
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 19, train_loss: 0.011190, valid_loss: 0.009255
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 20, train_loss: 0.011115, valid_loss: 0.009184
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 21, train_loss: 0.011018, valid_loss: 0.009120
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 22, train_loss: 0.010929, valid_loss: 0.009097
# SEED: 201, FOLD: 1, ALL_TARGETS, EPOCH: 23, train_loss: 0.010880, valid_loss: 0.009102
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 0, train_loss: 0.639587, valid_loss: 0.321042
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 1, train_loss: 0.056959, valid_loss: 0.021446
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 2, train_loss: 0.019031, valid_loss: 0.017536
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 3, train_loss: 0.017867, valid_loss: 0.017493
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 4, train_loss: 0.017636, valid_loss: 0.017371
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 5, train_loss: 0.017502, valid_loss: 0.017271
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 6, train_loss: 0.017860, valid_loss: 0.017367
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 7, train_loss: 0.017518, valid_loss: 0.017209
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 8, train_loss: 0.017389, valid_loss: 0.017216
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 9, train_loss: 0.017314, valid_loss: 0.017217
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 10, train_loss: 0.017234, valid_loss: 0.017270
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 11, train_loss: 0.017200, valid_loss: 0.017278
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 12, train_loss: 0.017383, valid_loss: 0.017236
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 13, train_loss: 0.017174, valid_loss: 0.017116
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 14, train_loss: 0.017083, valid_loss: 0.017141
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 15, train_loss: 0.016895, valid_loss: 0.017081
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 16, train_loss: 0.016780, valid_loss: 0.017052
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 17, train_loss: 0.016674, valid_loss: 0.017087
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 18, train_loss: 0.016764, valid_loss: 0.017200
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 19, train_loss: 0.016430, valid_loss: 0.017038
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 20, train_loss: 0.016152, valid_loss: 0.017064
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 21, train_loss: 0.015937, valid_loss: 0.017071
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 22, train_loss: 0.015798, valid_loss: 0.017042
# SEED: 201, FOLD: 1, SCORED_ONLY, EPOCH: 23, train_loss: 0.015738, valid_loss: 0.017035
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 0, train_loss: 0.495392, valid_loss: 0.020045
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 1, train_loss: 0.014116, valid_loss: 0.010144
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 2, train_loss: 0.012440, valid_loss: 0.012067
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 3, train_loss: 0.012166, valid_loss: 0.010887
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 4, train_loss: 0.011954, valid_loss: 0.009364
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 5, train_loss: 0.011824, valid_loss: 0.010123
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 6, train_loss: 0.011783, valid_loss: 0.010149
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 7, train_loss: 0.011947, valid_loss: 0.010030
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 8, train_loss: 0.011783, valid_loss: 0.009725
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 9, train_loss: 0.011735, valid_loss: 0.009152
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 10, train_loss: 0.011690, valid_loss: 0.009272
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 11, train_loss: 0.011695, valid_loss: 0.009097
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 12, train_loss: 0.011699, valid_loss: 0.009122
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 13, train_loss: 0.011635, valid_loss: 0.009108
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 14, train_loss: 0.011580, valid_loss: 0.008966
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 15, train_loss: 0.011568, valid_loss: 0.008971
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 16, train_loss: 0.011522, valid_loss: 0.008968
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 17, train_loss: 0.011468, valid_loss: 0.008883
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 18, train_loss: 0.011388, valid_loss: 0.008884
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 19, train_loss: 0.011291, valid_loss: 0.008798
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 20, train_loss: 0.011214, valid_loss: 0.008769
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 21, train_loss: 0.011114, valid_loss: 0.008699
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 22, train_loss: 0.011027, valid_loss: 0.008663
# SEED: 201, FOLD: 2, ALL_TARGETS, EPOCH: 23, train_loss: 0.010972, valid_loss: 0.008654
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 0, train_loss: 0.636455, valid_loss: 0.257513
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 1, train_loss: 0.056465, valid_loss: 0.018317
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 2, train_loss: 0.019153, valid_loss: 0.017236
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 3, train_loss: 0.018035, valid_loss: 0.016791
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 4, train_loss: 0.017814, valid_loss: 0.016774
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 5, train_loss: 0.017736, valid_loss: 0.016611
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 6, train_loss: 0.017898, valid_loss: 0.016709
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 7, train_loss: 0.017671, valid_loss: 0.016601
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 8, train_loss: 0.017576, valid_loss: 0.016530
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 9, train_loss: 0.017454, valid_loss: 0.016434
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 10, train_loss: 0.017415, valid_loss: 0.016704
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 11, train_loss: 0.017360, valid_loss: 0.016486
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 12, train_loss: 0.017567, valid_loss: 0.016538
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 13, train_loss: 0.017391, valid_loss: 0.016500
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 14, train_loss: 0.017225, valid_loss: 0.016465
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 15, train_loss: 0.017075, valid_loss: 0.016436
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 16, train_loss: 0.016922, valid_loss: 0.016370
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 17, train_loss: 0.016877, valid_loss: 0.016362
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 18, train_loss: 0.017044, valid_loss: 0.016364
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 19, train_loss: 0.016711, valid_loss: 0.016284
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 20, train_loss: 0.016390, valid_loss: 0.016290
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 21, train_loss: 0.016147, valid_loss: 0.016247
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 22, train_loss: 0.016035, valid_loss: 0.016249
# SEED: 201, FOLD: 2, SCORED_ONLY, EPOCH: 23, train_loss: 0.015956, valid_loss: 0.016221
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 0, train_loss: 0.496494, valid_loss: 0.022369
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 1, train_loss: 0.014685, valid_loss: 0.010578
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 2, train_loss: 0.012271, valid_loss: 0.009803
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 3, train_loss: 0.012201, valid_loss: 0.009739
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 4, train_loss: 0.011758, valid_loss: 0.009593
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 5, train_loss: 0.011636, valid_loss: 0.012749
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 6, train_loss: 0.011724, valid_loss: 0.009619
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 7, train_loss: 0.011612, valid_loss: 0.009871
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 8, train_loss: 0.011613, valid_loss: 0.009478
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 9, train_loss: 0.011602, valid_loss: 0.009596
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 10, train_loss: 0.011565, valid_loss: 0.009471
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 11, train_loss: 0.011571, valid_loss: 0.010004
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 12, train_loss: 0.011551, valid_loss: 0.009435
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 13, train_loss: 0.011507, valid_loss: 0.009510
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 14, train_loss: 0.011498, valid_loss: 0.009435
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 15, train_loss: 0.011469, valid_loss: 0.009397
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 16, train_loss: 0.011407, valid_loss: 0.009326
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 17, train_loss: 0.011354, valid_loss: 0.009262
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 18, train_loss: 0.011288, valid_loss: 0.009258
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 19, train_loss: 0.011200, valid_loss: 0.009218
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 20, train_loss: 0.011110, valid_loss: 0.009119
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 21, train_loss: 0.011010, valid_loss: 0.009077
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 22, train_loss: 0.010926, valid_loss: 0.009060
# SEED: 201, FOLD: 3, ALL_TARGETS, EPOCH: 23, train_loss: 0.010881, valid_loss: 0.009043
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 0, train_loss: 0.639611, valid_loss: 0.244103
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 1, train_loss: 0.056806, valid_loss: 0.021098
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 2, train_loss: 0.019261, valid_loss: 0.017537
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 3, train_loss: 0.017859, valid_loss: 0.017235
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 4, train_loss: 0.017577, valid_loss: 0.017274
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 5, train_loss: 0.017480, valid_loss: 0.017153
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 6, train_loss: 0.017675, valid_loss: 0.017287
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 7, train_loss: 0.017447, valid_loss: 0.017081
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 8, train_loss: 0.017346, valid_loss: 0.017245
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 9, train_loss: 0.017276, valid_loss: 0.017128
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 10, train_loss: 0.017217, valid_loss: 0.017076
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 11, train_loss: 0.017157, valid_loss: 0.017117
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 12, train_loss: 0.017395, valid_loss: 0.017019
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 13, train_loss: 0.017159, valid_loss: 0.017016
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 14, train_loss: 0.016969, valid_loss: 0.017045
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 15, train_loss: 0.016872, valid_loss: 0.016985
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 16, train_loss: 0.016706, valid_loss: 0.017008
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 17, train_loss: 0.016635, valid_loss: 0.017096
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 18, train_loss: 0.016744, valid_loss: 0.017007
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 19, train_loss: 0.016373, valid_loss: 0.017062
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 20, train_loss: 0.016039, valid_loss: 0.017047
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 21, train_loss: 0.015844, valid_loss: 0.017075
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 22, train_loss: 0.015668, valid_loss: 0.017074
# SEED: 201, FOLD: 3, SCORED_ONLY, EPOCH: 23, train_loss: 0.015602, valid_loss: 0.017077
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 0, train_loss: 0.496631, valid_loss: 0.020775
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 1, train_loss: 0.014071, valid_loss: 0.010514
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 2, train_loss: 0.012023, valid_loss: 0.009903
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 3, train_loss: 0.012096, valid_loss: 0.009580
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 4, train_loss: 0.011692, valid_loss: 0.009746
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 5, train_loss: 0.011543, valid_loss: 0.009587
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 6, train_loss: 0.011701, valid_loss: 0.009554
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 7, train_loss: 0.011609, valid_loss: 0.009620
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 8, train_loss: 0.011561, valid_loss: 0.009741
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 9, train_loss: 0.011583, valid_loss: 0.009737
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 10, train_loss: 0.011580, valid_loss: 0.009580
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 11, train_loss: 0.011553, valid_loss: 0.009507
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 12, train_loss: 0.011533, valid_loss: 0.009613
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 13, train_loss: 0.011517, valid_loss: 0.009599
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 14, train_loss: 0.011496, valid_loss: 0.009469
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 15, train_loss: 0.011446, valid_loss: 0.009450
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 16, train_loss: 0.011407, valid_loss: 0.009436
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 17, train_loss: 0.011340, valid_loss: 0.009363
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 18, train_loss: 0.011271, valid_loss: 0.009272
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 19, train_loss: 0.011180, valid_loss: 0.009248
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 20, train_loss: 0.011098, valid_loss: 0.009235
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 21, train_loss: 0.011006, valid_loss: 0.009148
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 22, train_loss: 0.010922, valid_loss: 0.009134
# SEED: 201, FOLD: 4, ALL_TARGETS, EPOCH: 23, train_loss: 0.010874, valid_loss: 0.009117
# SEED: 201, FOLD: 4, SCORED_ONLY, EPOCH: 0, train_loss: 0.638613, valid_loss: 0.323517
# SEED: 201, FOLD: 4, SCORED_ONLY, EPOCH: 1, train_loss: 0.056635, valid_loss: 0.020398
# ...
# SEED: 209, FOLD: 3, ALL_TARGETS, EPOCH: 8, train_loss: 0.011563, valid_loss: 0.009724
# SEED: 209, FOLD: 3, ALL_TARGETS, EPOCH: 9, train_loss: 0.011558, valid_loss: 0.009495
# SEED: 209, FOLD: 3, ALL_TARGETS, EPOCH: 10, train_loss: 0.011553, valid_loss: 0.009692
# SEED: 209, FOLD: 3, ALL_TARGETS, EPOCH: 11, train_loss: 0.011546, valid_loss: 0.009831
# SEED: 209, FOLD: 3, ALL_TARGETS, EPOCH: 12, train_loss: 0.011551, valid_loss: 0.009580
# SEED: 209, FOLD: 3, ALL_TARGETS, EPOCH: 13, train_loss: 0.011510, valid_loss: 0.009493
# SEED: 209, FOLD: 3, ALL_TARGETS, EPOCH: 14, train_loss: 0.011477, valid_loss: 0.009529
# SEED: 209, FOLD: 3, ALL_TARGETS, EPOCH: 15, train_loss: 0.011440, valid_loss: 0.009432
# SEED: 209, FOLD: 3, ALL_TARGETS, EPOCH: 16, train_loss: 0.011403, valid_loss: 0.009387
# SEED: 209, FOLD: 3, ALL_TARGETS, EPOCH: 17, train_loss: 0.011319, valid_loss: 0.009297
# SEED: 209, FOLD: 3, ALL_TARGETS, EPOCH: 18, train_loss: 0.011243, valid_loss: 0.009294
# SEED: 209, FOLD: 3, ALL_TARGETS, EPOCH: 19, train_loss: 0.011182, valid_loss: 0.009237
# SEED: 209, FOLD: 3, ALL_TARGETS, EPOCH: 20, train_loss: 0.011080, valid_loss: 0.009176
# SEED: 209, FOLD: 3, ALL_TARGETS, EPOCH: 21, train_loss: 0.010976, valid_loss: 0.009176
# SEED: 209, FOLD: 3, ALL_TARGETS, EPOCH: 22, train_loss: 0.010890, valid_loss: 0.009126
# SEED: 209, FOLD: 3, ALL_TARGETS, EPOCH: 23, train_loss: 0.010854, valid_loss: 0.009140
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 0, train_loss: 0.638590, valid_loss: 0.481542
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 1, train_loss: 0.057261, valid_loss: 0.019568
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 2, train_loss: 0.018884, valid_loss: 0.018114
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 3, train_loss: 0.017794, valid_loss: 0.017752
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 4, train_loss: 0.017641, valid_loss: 0.017738
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 5, train_loss: 0.017479, valid_loss: 0.017659
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 6, train_loss: 0.017621, valid_loss: 0.017689
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 7, train_loss: 0.017399, valid_loss: 0.017588
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 8, train_loss: 0.017287, valid_loss: 0.017643
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 9, train_loss: 0.017348, valid_loss: 0.017681
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 10, train_loss: 0.017231, valid_loss: 0.017581
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 11, train_loss: 0.017126, valid_loss: 0.017655
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 12, train_loss: 0.017348, valid_loss: 0.017505
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 13, train_loss: 0.017105, valid_loss: 0.017638
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 14, train_loss: 0.016978, valid_loss: 0.017449
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 15, train_loss: 0.016829, valid_loss: 0.017495
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 16, train_loss: 0.016744, valid_loss: 0.017566
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 17, train_loss: 0.016656, valid_loss: 0.017535
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 18, train_loss: 0.016804, valid_loss: 0.017515
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 19, train_loss: 0.016432, valid_loss: 0.017446
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 20, train_loss: 0.016128, valid_loss: 0.017436
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 21, train_loss: 0.015902, valid_loss: 0.017388
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 22, train_loss: 0.015751, valid_loss: 0.017445
# SEED: 209, FOLD: 3, SCORED_ONLY, EPOCH: 23, train_loss: 0.015689, valid_loss: 0.017413
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 0, train_loss: 0.495982, valid_loss: 0.020062
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 1, train_loss: 0.014222, valid_loss: 0.010574
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 2, train_loss: 0.011982, valid_loss: 0.009920
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 3, train_loss: 0.011718, valid_loss: 0.009806
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 4, train_loss: 0.011512, valid_loss: 0.009672
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 5, train_loss: 0.011515, valid_loss: 0.009639
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 6, train_loss: 0.011545, valid_loss: 0.009974
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 7, train_loss: 0.011573, valid_loss: 0.009612
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 8, train_loss: 0.011549, valid_loss: 0.009722
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 9, train_loss: 0.011532, valid_loss: 0.009779
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 10, train_loss: 0.011531, valid_loss: 0.009627
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 11, train_loss: 0.011498, valid_loss: 0.009717
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 12, train_loss: 0.011499, valid_loss: 0.009813
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 13, train_loss: 0.011491, valid_loss: 0.009532
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 14, train_loss: 0.011447, valid_loss: 0.009575
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 15, train_loss: 0.011410, valid_loss: 0.009561
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 16, train_loss: 0.011356, valid_loss: 0.009513
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 17, train_loss: 0.011303, valid_loss: 0.009519
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 18, train_loss: 0.011212, valid_loss: 0.009420
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 19, train_loss: 0.011143, valid_loss: 0.009371
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 20, train_loss: 0.011042, valid_loss: 0.009340
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 21, train_loss: 0.010956, valid_loss: 0.009301
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 22, train_loss: 0.010868, valid_loss: 0.009275
# SEED: 209, FOLD: 4, ALL_TARGETS, EPOCH: 23, train_loss: 0.010821, valid_loss: 0.009276
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 0, train_loss: 0.638789, valid_loss: 0.400200
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 1, train_loss: 0.057399, valid_loss: 0.020562
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 2, train_loss: 0.018943, valid_loss: 0.018357
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 3, train_loss: 0.017754, valid_loss: 0.017799
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 4, train_loss: 0.017526, valid_loss: 0.017788
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 5, train_loss: 0.017380, valid_loss: 0.017784
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 6, train_loss: 0.018863, valid_loss: 0.017975
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 7, train_loss: 0.017976, valid_loss: 0.017656
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 8, train_loss: 0.017470, valid_loss: 0.017624
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 9, train_loss: 0.017347, valid_loss: 0.017733
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 10, train_loss: 0.017282, valid_loss: 0.017679
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 11, train_loss: 0.017181, valid_loss: 0.017688
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 12, train_loss: 0.017507, valid_loss: 0.017770
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 13, train_loss: 0.017223, valid_loss: 0.017644
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 14, train_loss: 0.017047, valid_loss: 0.017592
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 15, train_loss: 0.016942, valid_loss: 0.017615
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 16, train_loss: 0.016814, valid_loss: 0.017561
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 17, train_loss: 0.016697, valid_loss: 0.017610
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 18, train_loss: 0.016836, valid_loss: 0.017578
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 19, train_loss: 0.016468, valid_loss: 0.017635
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 20, train_loss: 0.016163, valid_loss: 0.017606
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 21, train_loss: 0.015917, valid_loss: 0.017671
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 22, train_loss: 0.015750, valid_loss: 0.017599
# SEED: 209, FOLD: 4, SCORED_ONLY, EPOCH: 23, train_loss: 0.015656, valid_loss: 0.017609
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 0, train_loss: 0.497362, valid_loss: 0.020450
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 1, train_loss: 0.014277, valid_loss: 0.010461
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 2, train_loss: 0.012622, valid_loss: 0.009621
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 3, train_loss: 0.011633, valid_loss: 0.009555
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 4, train_loss: 0.011654, valid_loss: 0.009541
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 5, train_loss: 0.011612, valid_loss: 0.009598
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 6, train_loss: 0.011596, valid_loss: 0.009412
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 7, train_loss: 0.011670, valid_loss: 0.009658
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 8, train_loss: 0.011607, valid_loss: 0.009505
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 9, train_loss: 0.011623, valid_loss: 0.009438
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 10, train_loss: 0.011599, valid_loss: 0.009656
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 11, train_loss: 0.011591, valid_loss: 0.009345
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 12, train_loss: 0.011545, valid_loss: 0.009483
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 13, train_loss: 0.011545, valid_loss: 0.009505
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 14, train_loss: 0.011537, valid_loss: 0.009398
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 15, train_loss: 0.011475, valid_loss: 0.009352
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 16, train_loss: 0.011425, valid_loss: 0.009274
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 17, train_loss: 0.011358, valid_loss: 0.009233
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 18, train_loss: 0.011293, valid_loss: 0.009208
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 19, train_loss: 0.011217, valid_loss: 0.009127
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 20, train_loss: 0.011117, valid_loss: 0.009061
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 21, train_loss: 0.011016, valid_loss: 0.009020
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 22, train_loss: 0.010937, valid_loss: 0.008995
# SEED: 209, FOLD: 5, ALL_TARGETS, EPOCH: 23, train_loss: 0.010890, valid_loss: 0.008993
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 0, train_loss: 0.639513, valid_loss: 0.241574
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 1, train_loss: 0.057066, valid_loss: 0.019878
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 2, train_loss: 0.019250, valid_loss: 0.017961
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 3, train_loss: 0.017888, valid_loss: 0.017855
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 4, train_loss: 0.017581, valid_loss: 0.017644
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 5, train_loss: 0.017493, valid_loss: 0.017569
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 6, train_loss: 0.018064, valid_loss: 0.017652
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 7, train_loss: 0.017578, valid_loss: 0.017546
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 8, train_loss: 0.017385, valid_loss: 0.017556
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 9, train_loss: 0.017308, valid_loss: 0.017532
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 10, train_loss: 0.017251, valid_loss: 0.017475
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 11, train_loss: 0.017186, valid_loss: 0.017514
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 12, train_loss: 0.017458, valid_loss: 0.017636
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 13, train_loss: 0.017179, valid_loss: 0.017405
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 14, train_loss: 0.017095, valid_loss: 0.017481
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 15, train_loss: 0.016948, valid_loss: 0.017448
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 16, train_loss: 0.016794, valid_loss: 0.017358
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 17, train_loss: 0.016735, valid_loss: 0.017387
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 18, train_loss: 0.016829, valid_loss: 0.017254
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 19, train_loss: 0.016486, valid_loss: 0.017239
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 20, train_loss: 0.016236, valid_loss: 0.017301
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 21, train_loss: 0.016041, valid_loss: 0.017242
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 22, train_loss: 0.015858, valid_loss: 0.017217
# SEED: 209, FOLD: 5, SCORED_ONLY, EPOCH: 23, train_loss: 0.015813, valid_loss: 0.017241
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 0, train_loss: 0.494627, valid_loss: 0.018675
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 1, train_loss: 0.014223, valid_loss: 0.009637
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 2, train_loss: 0.012799, valid_loss: 0.015518
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 3, train_loss: 0.012119, valid_loss: 0.011368
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 4, train_loss: 0.011909, valid_loss: 0.009564
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 5, train_loss: 0.011777, valid_loss: 0.009660
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 6, train_loss: 0.011725, valid_loss: 0.010236
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 7, train_loss: 0.011748, valid_loss: 0.008821
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 8, train_loss: 0.011693, valid_loss: 0.009132
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 9, train_loss: 0.011713, valid_loss: 0.008889
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 10, train_loss: 0.011644, valid_loss: 0.009043
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 11, train_loss: 0.011647, valid_loss: 0.008877
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 12, train_loss: 0.011682, valid_loss: 0.008805
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 13, train_loss: 0.011646, valid_loss: 0.008865
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 14, train_loss: 0.011605, valid_loss: 0.008738
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 15, train_loss: 0.011561, valid_loss: 0.008715
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 16, train_loss: 0.011521, valid_loss: 0.008644
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 17, train_loss: 0.011434, valid_loss: 0.008669
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 18, train_loss: 0.011409, valid_loss: 0.008582
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 19, train_loss: 0.011303, valid_loss: 0.008504
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 20, train_loss: 0.011221, valid_loss: 0.008509
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 21, train_loss: 0.011083, valid_loss: 0.008424
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 22, train_loss: 0.011014, valid_loss: 0.008427
# SEED: 209, FOLD: 6, ALL_TARGETS, EPOCH: 23, train_loss: 0.010961, valid_loss: 0.008432
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 0, train_loss: 0.639824, valid_loss: 0.237323
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 1, train_loss: 0.057467, valid_loss: 0.020560
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 2, train_loss: 0.019033, valid_loss: 0.017391
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 3, train_loss: 0.017992, valid_loss: 0.017059
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 4, train_loss: 0.017749, valid_loss: 0.016822
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 5, train_loss: 0.017595, valid_loss: 0.016799
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 6, train_loss: 0.017997, valid_loss: 0.016693
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 7, train_loss: 0.017540, valid_loss: 0.016782
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 8, train_loss: 0.017485, valid_loss: 0.016850
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 9, train_loss: 0.017417, valid_loss: 0.016844
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 10, train_loss: 0.017379, valid_loss: 0.016812
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 11, train_loss: 0.017301, valid_loss: 0.016834
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 12, train_loss: 0.017551, valid_loss: 0.016922
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 13, train_loss: 0.017227, valid_loss: 0.016753
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 14, train_loss: 0.017153, valid_loss: 0.016579
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 15, train_loss: 0.017018, valid_loss: 0.016622
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 16, train_loss: 0.016927, valid_loss: 0.016623
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 17, train_loss: 0.016814, valid_loss: 0.016523
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 18, train_loss: 0.016922, valid_loss: 0.016640
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 19, train_loss: 0.016489, valid_loss: 0.016550
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 20, train_loss: 0.016201, valid_loss: 0.016619
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 21, train_loss: 0.015985, valid_loss: 0.016619
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 22, train_loss: 0.015849, valid_loss: 0.016629
# SEED: 209, FOLD: 6, SCORED_ONLY, EPOCH: 23, train_loss: 0.015804, valid_loss: 0.016674
# 0.016898108835319482

# %%
pd.DataFrame(sc_dic,index=['sc']).T
# Out:
#            sc
# 200  0.017226
# 201  0.017033
# 202  0.016982
# 203  0.016948
# 204  0.016924
# 205  0.016919
# 206  0.016910
# 207  0.016906
# 208  0.016903
# 209  0.016898
